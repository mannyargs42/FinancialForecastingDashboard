# %%
# Install PostgreSQL
# !apt-get -y -qq install postgresql-14 >/dev/null

# Start the PostgreSQL server
# !sudo service postgresql start

# Create the new database user and set its password
# !sudo -u postgres psql -c "CREATE USER root WITH PASSWORD 'root';"

# Create the database and grant permissions
# !sudo -u postgres createdb financial_data

# Grant all privileges on the new database to the new user
# !sudo -u postgres psql -c "GRANT ALL PRIVILEGES ON DATABASE financial_data TO root;"
# Out:
#  * Starting PostgreSQL 14 database server
#    ...done.
# CREATE ROLE
# GRANT

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/scripts"
# Out:
# /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/scripts

# %%
from google.colab import userdata
import os

os.environ['DB_HOST'] = userdata.get('DB_HOST')
os.environ['DB_PORT'] = userdata.get('DB_PORT')
os.environ['DB_NAME'] = userdata.get('DB_NAME')
os.environ['DB_USER'] = userdata.get('DB_USER')
os.environ['DB_PASS'] = userdata.get('DB_PASS')

print("Environment variables for database connection have been set.")
# Out:
# Environment variables for database connection have been set.

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/scripts/database_setup.py"
# Out:
# Successfully connected to the database.
# Table 'raw_saas_metrics' is ready.
# Successfully ingested 5000 records into raw_saas_metrics.
# Database connection closed.
