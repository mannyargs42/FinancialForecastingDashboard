# %% [markdown]
# ---Start by setting up PostgreSQL server and user, then running the ingestion script database_setup.py---

# %%
import os
from google.colab import userdata

# Get username and password from Colab secrets
db_user = userdata.get('DB_USER')
db_pass = userdata.get('DB_PASS')

# Install PostgreSQL
# !apt-get -y -qq install postgresql-14 >/dev/null

# Start the PostgreSQL server
# !sudo service postgresql start

# Create the new database user and set its password from the secret
# !sudo -u postgres psql -c "CREATE USER {db_user} WITH PASSWORD '{db_pass}';"

# Create the database and grant permissions
# !sudo -u postgres createdb financial_data

# Grant all privileges on the new database to the new user
# !sudo -u postgres psql -c "GRANT ALL PRIVILEGES ON DATABASE financial_data TO {db_user};"

# Install dbt and its postgres adapter
# !pip install dbt-postgres
# Out:
#  * Starting PostgreSQL 14 database server
#    ...done.
# ERROR:  role "root" already exists
# createdb: error: database creation failed: ERROR:  database "financial_data" already exists
# GRANT
# Requirement already satisfied: dbt-postgres in /usr/local/lib/python3.12/dist-packages (1.9.1)
# Requirement already satisfied: agate<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.9.1)
# Requirement already satisfied: dbt-adapters<2.0,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.16.7)
# Requirement already satisfied: dbt-common<2.0,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.31.0)
# Requirement already satisfied: dbt-core>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.10.11)
# Requirement already satisfied: psycopg2-binary<3.0,>=2.9 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (2.9.10)
# Requirement already satisfied: Babel>=2.0 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (2.17.0)
# Requirement already satisfied: isodate>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (0.6.1)
# Requirement already satisfied: leather>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (0.4.0)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (1.1.8)
# Requirement already satisfied: dbt-protos<2.0,>=1.0.291 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (1.0.375)
# Requirement already satisfied: mashumaro<3.15,>=3.9 in /usr/local/lib/python3.12/dist-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.7.0->dbt-postgres) (3.14)
# Requirement already satisfied: protobuf<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (6.32.1)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (2025.2)
# Requirement already satisfied: typing-extensions<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (4.15.0)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (0.4.6)
# Requirement already satisfied: deepdiff<9.0,>=7.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (8.6.1)
# Requirement already satisfied: jinja2<4,>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (3.1.6)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (4.25.1)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (0.12.1)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (2.32.4)
# Requirement already satisfied: click<9.0,>=8.0.2 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (8.2.1)
# Requirement already satisfied: networkx<4.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (3.5)
# Requirement already satisfied: snowplow-tracker<2.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (1.1.0)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (0.5.3)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (0.6.0)
# Requirement already satisfied: dbt-semantic-interfaces<0.10,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (0.9.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (2.11.9)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (25.0)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (6.0.2)
# Requirement already satisfied: daff>=1.3.46 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (1.4.2)
# Requirement already satisfied: importlib-metadata<9,>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (8.7.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (10.8.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from deepdiff<9.0,>=7.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from isodate>=0.5.4->agate<2.0,>=1.0->dbt-postgres) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4,>=3.1.3->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (0.27.1)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.7.0->dbt-postgres) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (0.4.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify>=1.2.1->agate<2.0,>=1.0->dbt-postgres) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2025.8.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9,>=6.0->dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (3.23.0)

# %%
# Change to project's root directory
# %cd "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard"
# Out:
# /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard

# %%
# check if raw_saas_data.json is in directory
# !ls -F
# Out:
# financial_forecasting/	logs/	    raw_saas_data.json	scripts/
# LICENSE			notebooks/  README.md

# %%
# Get the rest of the environment variables from Colab secrets.
db_host = userdata.get('DB_HOST')
db_port = userdata.get('DB_PORT')
db_name = userdata.get('DB_NAME')

# !DB_HOST={db_host} DB_PORT={db_port} DB_NAME={db_name} DB_USER={db_user} DB_PASS={db_pass} python "scripts/database_setup.py"
# Out:
# Successfully connected to the database.
# Table 'raw_saas_metrics' is ready.
# Successfully ingested 5000 records into raw_saas_metrics.
# Database connection closed.

# %% [markdown]
# --- Set up dbt ---

# %%
# !pip install dbt-postgres
# Out:
# Requirement already satisfied: dbt-postgres in /usr/local/lib/python3.12/dist-packages (1.9.1)
# Requirement already satisfied: agate<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.9.1)
# Requirement already satisfied: dbt-adapters<2.0,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.16.7)
# Requirement already satisfied: dbt-common<2.0,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.31.0)
# Requirement already satisfied: dbt-core>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (1.10.11)
# Requirement already satisfied: psycopg2-binary<3.0,>=2.9 in /usr/local/lib/python3.12/dist-packages (from dbt-postgres) (2.9.10)
# Requirement already satisfied: Babel>=2.0 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (2.17.0)
# Requirement already satisfied: isodate>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (0.6.1)
# Requirement already satisfied: leather>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (0.4.0)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (1.1.8)
# Requirement already satisfied: dbt-protos<2.0,>=1.0.291 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (1.0.375)
# Requirement already satisfied: mashumaro<3.15,>=3.9 in /usr/local/lib/python3.12/dist-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.7.0->dbt-postgres) (3.14)
# Requirement already satisfied: protobuf<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (6.32.1)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (2025.2)
# Requirement already satisfied: typing-extensions<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (4.15.0)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (0.4.6)
# Requirement already satisfied: deepdiff<9.0,>=7.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (8.6.1)
# Requirement already satisfied: jinja2<4,>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (3.1.6)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (4.25.1)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (0.12.1)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (2.32.4)
# Requirement already satisfied: click<9.0,>=8.0.2 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (8.2.1)
# Requirement already satisfied: networkx<4.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (3.5)
# Requirement already satisfied: snowplow-tracker<2.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (1.1.0)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (0.5.3)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (0.6.0)
# Requirement already satisfied: dbt-semantic-interfaces<0.10,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (0.9.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (2.11.9)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (25.0)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (6.0.2)
# Requirement already satisfied: daff>=1.3.46 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (1.4.2)
# Requirement already satisfied: importlib-metadata<9,>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (8.7.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (10.8.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from deepdiff<9.0,>=7.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from isodate>=0.5.4->agate<2.0,>=1.0->dbt-postgres) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4,>=3.1.3->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (0.27.1)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.7.0->dbt-postgres) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (0.4.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify>=1.2.1->agate<2.0,>=1.0->dbt-postgres) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2025.8.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9,>=6.0->dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (3.23.0)

# %%
# Initialize a new dbt project without prompting for input
# !dbt init financial_forecasting --profiles-dir /root/.dbt
# Out:
# 06:40:38  Running with dbt=1.10.11
# 06:40:38  Creating dbt configuration folder at /root/.dbt
# 06:40:38  A project called financial_forecasting already exists here.

# %%
from google.colab import userdata
import os

# Create the .dbt directory, if it doesn't exist.
dbt_dir = os.path.join(os.path.expanduser("~"), ".dbt")
if not os.path.exists(dbt_dir):
  os.makedirs(dbt_dir)

# Define the content of profiles.yml file.
profiles_content = f"""
financial_forecasting:
  target: dev
  outputs:
    dev:
      type: postgres
      host: {userdata.get('DB_HOST')}
      port: {userdata.get('DB_PORT')}
      user: {userdata.get('DB_USER')}
      password: {userdata.get('DB_PASS')}
      dbname: {userdata.get('DB_NAME')}
      schema: public
"""

# Write the content to the profiles.yml file
profiles_path = os.path.join(dbt_dir, "profiles.yml")
with open(profiles_path, "w") as f:
  f.write(profiles_content)
print("dbt profiles.yml file has been created successfully.")
# Out:
# dbt profiles.yml file has been created successfully.

# %%
# Change to dbt project's directory
# %cd "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting"
# Out:
# /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting

# %%
# Verify the set up, test connection to db
# !dbt debug --profiles-dir ~/.dbt --project-dir .
# Out:
# 06:42:09  Running with dbt=1.10.11
# 06:42:09  dbt version: 1.10.11
# 06:42:09  python version: 3.12.11
# 06:42:09  python path: /usr/bin/python3
# 06:42:09  os info: Linux-6.6.97+-x86_64-with-glibc2.35
# 06:42:09  Using profiles dir at /root/.dbt
# 06:42:09  Using profiles.yml file at /root/.dbt/profiles.yml
# 06:42:09  Using dbt_project.yml file at ./dbt_project.yml
# 06:42:09  adapter type: postgres
# 06:42:09  adapter version: 1.9.1
# 06:42:10  Configuration:
# 06:42:10    profiles.yml file [OK found and valid]
# 06:42:10    dbt_project.yml file [OK found and valid]
# 06:42:10  Required dependencies:
# 06:42:10   - git [OK found]
#
# 06:42:10  Connection:
# 06:42:10    host: localhost
# 06:42:10    port: 5432
# 06:42:10    user: root
# 06:42:10    database: financial_data
# 06:42:10    schema: public
# 06:42:10    connect_timeout: 10
# 06:42:10    role: None
# 06:42:10    search_path: None
# 06:42:10    keepalives_idle: 0
# 06:42:10    sslmode: None
# 06:42:10    sslcert: None
# 06:42:10    sslkey: None
# 06:42:10    sslrootcert: None
# 06:42:10    application_name: dbt
# 06:42:10    retries: 1
# 06:42:10  Registered adapter: postgres=1.9.1
# 06:42:10    Connection test: [OK connection ok]
#
# 06:42:10  All checks passed!

# %%
# Change to dbt project's directory
# %cd "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting"
# Out:
# /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting

# %%
# Create a folder for the raw_saas_data staging models
# !mkdir -p models/staging

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting/models/staging/sources.yml"
#
# # Write a sources.yml model for dbt to recognize and document raw data tables
#
# version: 2
#
# sources:
#   - name: raw
#     description: "Raw data ingested from external sources."
#     schema: public
#     tables:
#       - name: raw_saas_metrics
#         description: "Raw financial metrics data ingested from a JSON file."
#         tests:
#           - not_null:
#               column_name: "customer_id"
# Out:
# Writing /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting/models/staging/sources.yml

# %% [markdown]
# ---For building the staging layer---

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting/models/staging/stg_raw_saas_metrics_data.sql"
#
# -- This staging model performs initial cleaning on the raw saas data.
# -- It selects data from the source table (from sources.yml), standardizes column names,
#   --and casts the data into the correct types.
#
# WITH source_data AS (
#     SELECT
#         customer_id,
#         subscription_start_date,
#         monthly_recurring_revenue,
#         churn_date,
#         plan_type
#     FROM
#         {{ source('raw', 'raw_saas_metrics') }}
# )
#
# SELECT
#     CAST(customer_id AS INTEGER) AS customer_id,
#     CAST(subscription_start_date AS DATE) AS subscription_start_date,
#     CAST(monthly_recurring_revenue AS NUMERIC) AS monthly_recurring_revenue,
#     CAST(churn_date AS DATE) AS churn_date,
#     CAST(plan_type AS VARCHAR) AS plan_type
# FROM
#     source_data
# Out:
# Writing /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting/models/staging/stg_raw_saas_metrics_data.sql

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting/models/staging/schema.yml"
#
# # This file holds the tests for the new staging model.
# # It performs basic data quality checks for the customer_id & subscription_start_date cols.
#
#
# version: 2
#
# models:
#   - name: stg_raw_saas_metrics
#     description: "Staging model for raw SaaS metrics data."
#     columns:
#       - name: customer_id
#         description: "The unique identifier for a customer."
#         tests:
#           - unique
#           - not_null
#       - name: subscription_start_date
#         description: "The date the customer's subscription began."
#         tests:
#           - not_null
# Out:
# Writing /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting/models/staging/schema.yml

# %%
# This command will update dbt's internal project graph and make it aware of the new
  # staging model and its tests.
# !dbt parse
# Out:
# 08:06:36  Running with dbt=1.10.11
# 08:06:37  Registered adapter: postgres=1.9.1
# 08:06:37  Performance info: /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting/target/perf_info.json

# %%
# Run the dbt model
# !dbt run
# Out:
# 08:06:44  Running with dbt=1.10.11
# 08:06:45  Registered adapter: postgres=1.9.1
# 08:06:46  Found 3 models, 5 data tests, 1 source, 434 macros
# 08:06:46
# 08:06:46  Concurrency: 1 threads (target='dev')
# 08:06:46
# 08:06:46  1 of 3 START sql table model public.my_first_dbt_model ......................... [RUN]
# 08:06:46  1 of 3 OK created sql table model public.my_first_dbt_model .................... [SELECT 2 in 0.18s]
# 08:06:46  2 of 3 START sql view model public.stg_raw_saas_metrics_data ................... [RUN]
# 08:06:46  2 of 3 OK created sql view model public.stg_raw_saas_metrics_data .............. [CREATE VIEW in 0.10s]
# 08:06:46  3 of 3 START sql view model public.my_second_dbt_model ......................... [RUN]
# 08:06:46  3 of 3 OK created sql view model public.my_second_dbt_model .................... [CREATE VIEW in 0.09s]
# 08:06:46
# 08:06:46  Finished running 1 table model, 2 view models in 0 hours 0 minutes and 0.56 seconds (0.56s).
# 08:06:46
# 08:06:46  Completed successfully
# 08:06:46
# 08:06:46  Done. PASS=3 WARN=0 ERROR=0 SKIP=0 NO-OP=0 TOTAL=3
