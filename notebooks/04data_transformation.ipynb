# %%
import os
from google.colab import userdata

# Get username and password from Colab secrets
db_user = userdata.get('DB_USER')
db_pass = userdata.get('DB_PASS')

# Install PostgreSQL
# !apt-get -y -qq install postgresql-14 >/dev/null

# Start the PostgreSQL server
# !sudo service postgresql start

# Create the new database user and set its password from the secret
# !sudo -u postgres psql -c "CREATE USER {db_user} WITH PASSWORD '{db_pass}';"

# Create the database and grant permissions
# !sudo -u postgres createdb financial_data

# Grant all privileges on the new database to the new user
# !sudo -u postgres psql -c "GRANT ALL PRIVILEGES ON DATABASE financial_data TO {db_user};"

# Install dbt and its postgres adapter
# !pip install dbt-postgres
# Out:
#  * Starting PostgreSQL 14 database server
#    ...done.
# CREATE ROLE
# GRANT
# Collecting dbt-postgres
#   Downloading dbt_postgres-1.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting agate<2.0,>=1.0 (from dbt-postgres)
#   Downloading agate-1.13.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting dbt-adapters<2.0,>=1.7.0 (from dbt-postgres)
#   Downloading dbt_adapters-1.16.7-py3-none-any.whl.metadata (4.5 kB)
# Collecting dbt-common<2.0,>=1.0.4 (from dbt-postgres)
#   Downloading dbt_common-1.30.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting dbt-core>=1.8.0 (from dbt-postgres)
#   Downloading dbt_core-1.10.11-py3-none-any.whl.metadata (4.2 kB)
# Collecting psycopg2-binary<3.0,>=2.9 (from dbt-postgres)
#   Downloading psycopg2_binary-2.9.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: Babel>=2.0 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (2.17.0)
# Collecting isodate>=0.5.4 (from agate<2.0,>=1.0->dbt-postgres)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting leather>=0.3.2 (from agate<2.0,>=1.0->dbt-postgres)
#   Downloading leather-0.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting parsedatetime!=2.5,>=2.1 (from agate<2.0,>=1.0->dbt-postgres)
#   Downloading parsedatetime-2.6-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: python-slugify>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-postgres) (8.0.4)
# Collecting pytimeparse>=1.1.5 (from agate<2.0,>=1.0->dbt-postgres)
#   Downloading pytimeparse-1.1.8-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting dbt-protos<2.0,>=1.0.291 (from dbt-adapters<2.0,>=1.7.0->dbt-postgres)
#   Downloading dbt_protos-1.0.375-py3-none-any.whl.metadata (859 bytes)
# Collecting mashumaro<3.15,>=3.9 (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.7.0->dbt-postgres)
#   Downloading mashumaro-3.14-py3-none-any.whl.metadata (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 kB 3.3 MB/s eta 0:00:00
# Collecting protobuf<7.0,>=6.0 (from dbt-adapters<2.0,>=1.7.0->dbt-postgres)
#   Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (2025.2)
# Requirement already satisfied: typing-extensions<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2.0,>=1.7.0->dbt-postgres) (4.15.0)
# Collecting agate<2.0,>=1.0 (from dbt-postgres)
#   Downloading agate-1.9.1-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting colorama<0.5,>=0.3.9 (from dbt-common<2.0,>=1.0.4->dbt-postgres)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting deepdiff<9.0,>=7.0 (from dbt-common<2.0,>=1.0.4->dbt-postgres)
#   Downloading deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting isodate>=0.5.4 (from agate<2.0,>=1.0->dbt-postgres)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: jinja2<4,>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (3.1.6)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (4.25.1)
# Collecting pathspec<0.13,>=0.9 (from dbt-common<2.0,>=1.0.4->dbt-postgres)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2.0,>=1.0.4->dbt-postgres) (2.32.4)
# Requirement already satisfied: click<9.0,>=8.0.2 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (8.2.1)
# Requirement already satisfied: networkx<4.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (3.5)
# Collecting snowplow-tracker<2.0,>=1.0.2 (from dbt-core>=1.8.0->dbt-postgres)
#   Downloading snowplow_tracker-1.1.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (0.5.3)
# Collecting dbt-extractor<=0.6,>=0.5.0 (from dbt-core>=1.8.0->dbt-postgres)
#   Downloading dbt_extractor-0.6.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Collecting dbt-semantic-interfaces<0.10,>=0.9.0 (from dbt-core>=1.8.0->dbt-postgres)
#   Downloading dbt_semantic_interfaces-0.9.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (2.11.7)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (25.0)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-postgres) (6.0.2)
# Collecting daff>=1.3.46 (from dbt-core>=1.8.0->dbt-postgres)
#   Downloading daff-1.4.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib-metadata<9,>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (8.7.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (10.8.0)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff<9.0,>=7.0->dbt-common<2.0,>=1.0.4->dbt-postgres)
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from isodate>=0.5.4->agate<2.0,>=1.0->dbt-postgres) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4,>=3.1.3->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (0.27.1)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.7.0->dbt-postgres) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-postgres) (0.4.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify>=1.2.1->agate<2.0,>=1.0->dbt-postgres) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0->dbt-common<2.0,>=1.0.4->dbt-postgres) (2025.8.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9,>=6.0->dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-postgres) (3.23.0)
# Downloading dbt_postgres-1.9.1-py3-none-any.whl (35 kB)
# Downloading dbt_adapters-1.16.7-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.7/167.7 kB 9.3 MB/s eta 0:00:00
# Downloading dbt_common-1.30.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 7.9 MB/s eta 0:00:00
# Downloading agate-1.9.1-py2.py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 7.7 MB/s eta 0:00:00
# Downloading dbt_core-1.10.11-py3-none-any.whl (984 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.5/984.5 kB 26.1 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 71.0 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading daff-1.4.2-py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.9/144.9 kB 12.6 MB/s eta 0:00:00
# Downloading dbt_extractor-0.6.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.7/442.7 kB 28.2 MB/s eta 0:00:00
# Downloading dbt_protos-1.0.375-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 7.6 MB/s eta 0:00:00
# Downloading dbt_semantic_interfaces-0.9.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 kB 12.4 MB/s eta 0:00:00
# Downloading deepdiff-8.6.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 7.4 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.9 MB/s eta 0:00:00
# Downloading leather-0.4.0-py2.py3-none-any.whl (30 kB)
# Downloading mashumaro-3.14-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 7.6 MB/s eta 0:00:00
# Downloading parsedatetime-2.6-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.0 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 24.0 MB/s eta 0:00:00
# Downloading pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Downloading snowplow_tracker-1.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.1 MB/s eta 0:00:00
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Installing collected packages: pytimeparse, parsedatetime, leather, daff, psycopg2-binary, protobuf, pathspec, orderly-set, mashumaro, isodate, dbt-extractor, colorama, snowplow-tracker, deepdiff, dbt-protos, agate, dbt-semantic-interfaces, dbt-common, dbt-adapters, dbt-core, dbt-postgres
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.32.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.32.1 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.1 which is incompatible.
# Successfully installed agate-1.9.1 colorama-0.4.6 daff-1.4.2 dbt-adapters-1.16.7 dbt-common-1.30.0 dbt-core-1.10.11 dbt-extractor-0.6.0 dbt-postgres-1.9.1 dbt-protos-1.0.375 dbt-semantic-interfaces-0.9.0 deepdiff-8.6.1 isodate-0.6.1 leather-0.4.0 mashumaro-3.14 orderly-set-5.5.0 parsedatetime-2.6 pathspec-0.12.1 protobuf-6.32.1 psycopg2-binary-2.9.10 pytimeparse-1.1.8 snowplow-tracker-1.1.0

# %%
# Change to project's root directory
# %cd "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard"
# Out:
# /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard

# %%
# Initialize a new dbt project without prompting for input
# !dbt init financial_forecasting --profiles-dir /root/.dbt
# Out:
# 05:52:14  Running with dbt=1.10.11
# 05:52:14  Creating dbt configuration folder at /root/.dbt
# 05:52:14  A project called financial_forecasting already exists here.

# %%
from google.colab import userdata
import os

# Create the .dbt directory, if it doesn't exist.
dbt_dir = os.path.join(os.path.expanduser("~"), ".dbt")
if not os.path.exists(dbt_dir):
  os.makedirs(dbt_dir)

# Define the content of profiles.yml file.
profiles_content = f"""
financial_forecasting:
  target: dev
  outputs:
    dev:
      type: postgres
      host: {userdata.get('DB_HOST')}
      port: {userdata.get('DB_PORT')}
      user: {userdata.get('DB_USER')}
      password: {userdata.get('DB_PASS')}
      dbname: {userdata.get('DB_NAME')}
      schema: public
"""

# Write the content to the profiles.yml file
profiles_path = os.path.join(dbt_dir, "profiles.yml")
with open(profiles_path, "w") as f:
  f.write(profiles_content)
print("dbt profiles.yml file has been created successfully.")
# Out:
# dbt profiles.yml file has been created successfully.

# %%
# Change to dbt project's directory
# %cd "/content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting"
# Out:
# /content/drive/MyDrive/Colab Notebooks/FinancialForecastingDashboard/financial_forecasting

# %%
# Verify the set up, test connection to db
# !dbt debug --profiles-dir ~/.dbt --project-dir .
# Out:
# 05:56:15  Running with dbt=1.10.11
# 05:56:15  dbt version: 1.10.11
# 05:56:15  python version: 3.12.11
# 05:56:15  python path: /usr/bin/python3
# 05:56:15  os info: Linux-6.1.123+-x86_64-with-glibc2.35
# 05:56:15  Using profiles dir at /root/.dbt
# 05:56:15  Using profiles.yml file at /root/.dbt/profiles.yml
# 05:56:15  Using dbt_project.yml file at ./dbt_project.yml
# 05:56:15  adapter type: postgres
# 05:56:15  adapter version: 1.9.1
# 05:56:16  Configuration:
# 05:56:16    profiles.yml file [OK found and valid]
# 05:56:16    dbt_project.yml file [OK found and valid]
# 05:56:16  Required dependencies:
# 05:56:16   - git [OK found]
#
# 05:56:16  Connection:
# 05:56:16    host: localhost
# 05:56:16    port: 5432
# 05:56:16    user: root
# 05:56:16    database: financial_data
# 05:56:16    schema: public
# 05:56:16    connect_timeout: 10
# 05:56:16    role: None
# 05:56:16    search_path: None
# 05:56:16    keepalives_idle: 0
# 05:56:16    sslmode: None
# 05:56:16    sslcert: None
# 05:56:16    sslkey: None
# 05:56:16    sslrootcert: None
# 05:56:16    application_name: dbt
# 05:56:16    retries: 1
# 05:56:16  Registered adapter: postgres=1.9.1
# 05:56:16    Connection test: [OK connection ok]
#
# 05:56:16  All checks passed!
